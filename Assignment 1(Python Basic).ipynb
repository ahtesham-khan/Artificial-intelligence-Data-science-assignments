# %% [markdown]
# #                     Python Basics Assignment

# %% [markdown]
# ## Topics: print(), Variables, Data Types, Arithmetic Operators, Logical Operators

# %% [markdown]
# ### 1. Student Information
# Create variables for a student's name, age, city, and student status. Print all the
# information in a properly formatted output.

# %%
student_name="Abdul Hadi Khan"
age= 8
city="Karachi"
student_status = "active"

print(student_name)
print(age)
print(city)
print(student_status)
# Out:
# Abdul Hadi Khan
# 8
# Karachi
# active

# %% [markdown]
# # 2. Data Types
# Create variables containing a string, integer, float, and boolean. Print the value and data
# type of each variable using type().

# %%
student_name="Abdul Hadi Khan"
age = 8
height =4.5 

print(type(student_name))
print(type(age))
print(type(height))
print(type(False))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ### 3. Arithmetic Operations
# Create two number variables and calculate their:
# • Addition
# • Subtraction
# • Multiplication
# • Division
# • Modulus
# • Power

# %%
num1=10
num2=20
print(num1+num2)
print(num2-num1)
print(num1*num2)
print(num2/num1)
print(num2//num1)
print(10**2)
# Out:
# 30
# 10
# 200
# 2.0
# 2
# 100

# %% [markdown]
# ### 4. Student Marks Calculator
# Store the marks of three subjects in separate variables. Calculate and print the total
# marks and average marks.

# %%
math_marks=10
english_marks=20
urdu_marks= 30

total_marks=math_marks+english_marks+urdu_marks
average_marks=(total_marks)/3

print("total marks is ",total_marks)
print("verage_marks is "average_marks)
# Out:
# total marks is  60
# 20.0

# %% [markdown]
# ### 5. Shopping Bill
# Create variables for the product price and quantity. Calculate and print the total bill.

# %%
product=10
quantity=5

total_bill=product*quantity

print("total bill is ",total_bill)
# Out:
# total bill is  50

# %% [markdown]
# ### 6. Rectangle Area
# Create variables for the length and width of a rectangle. Calculate and print its area and
# perimeter.

# %%
width= 5
height=10

area_of_rectangle=width*height
perimeter=2*(width+height)

print("area of rectangle =",area_of_rectangle)
print("perimeter =", perimeter)
# Out:
# area of rectangle = 50
# perimeter = 30

# %% [markdown]
# #### 7. Time Converter
# Store 250 minutes in a variable. Calculate and print the number of hours and remaining
# minutes.

# %%
time_in_minutes=250 

hours=time_in_minutes//60   #return interger value
minutes=time_in_minutes%60   #return reminder 


print("hours: ",hours)
print("minutes",minutes)
# Out:
# hours:  4
# minutes 10

# %% [markdown]
# ### 8. Student Eligibility
# Create variables for marks and attendance.
# A student is eligible if:
# • Marks are greater than or equal to 50
# • Attendance is greater than or equal to 75
# Use logical operators to calculate and print whether the student is eligible.

# %%
marks=int(input("Enter marks of student: "))
attendence=int(input("Enter the attendence of student: "))


if marks>=50 and attendence>=75:
    print("student is eligible ")
else:
    print("student is not eligible")
# Out:
# Enter marks of student:  60
# Enter the attendence of student:  75
# student is eligible

# %% [markdown]
# ### 9. Logical Operators
# Create two Boolean variables:
#
# a = True
#
# b = False
#
# Print the results of:
#
# • a and b
#
# • a or b
#
# • not a
#
# • not b

# %%
a=True
b=False

print(a and b)
print(a or b )
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# ### Final Challenge Student Report
# Create variables for:
#
# • Student name
# • Age
# • Marks of 3 subjects
# • Attendance
# Then:
# 1. Print the student's information.
# 2. Calculate and print the total marks.
# 3. Calculate and print the average marks.
# 4. Use logical operators to calculate and print whether the student is eligible:
# o Average marks >= 50
# o Attendance >= 75
# Restriction: Do not use if, else, or elif
# ###

# %%
student_name="Muhammad Ahtesham khan"
age=20
subject1=80
subject2=75
subject3=70
attendence=65

print("\t \t \t STUDENT INFORMATION")

print("student name is : ", student_name)
print("student age is  : ",age)
print("student attendence is  :",attendence)

total_marks=(subject1+subject2+subject3)
average_marks=total_marks/3

print("total marks is :",total_marks)
print("average marks is :",average_marks)


#print(average_marks>=50 and attendence >=75 ) 


is_eligible=(average_marks>=50) and (attendence >=75 ) 

status=("not eligible", "eligible")[is_eligible]

print(status)
# Out:
# 	 	 	 STUDENT INFORMATION
# student name is :  Muhammad Ahtesham khan
# student age is  :  20
# student attendence is  : 65
# total marks is : 225
# average marks is : 75.0
# not eligible
